# %% [markdown]
# # Crate Directory and Output File

# %%
#Use '/resource' to syncronize folder with host

# !mkdir -p ~/output/renamed-data/binary
# !mkdir -p ~/output/renamed-data/multi

# %%
read_path = "/home/jovyan/output/labeled-data/multi/FullDataResampling.csv"
write_path = "/home/jovyan/output/renamed-data/multi/FullDataResampling.csv"

# %% [markdown]
# # Import Package

# %%
import pandas as pd
import numpy as np

data= pd.read_csv(read_path)
data.head(4)
# Out:
#    Unnamed: 0                                       Flow ID          Src IP  \
# 0           0            172.16.0.11-212.95.7.75-4539-53-17     172.16.0.11
# 1           1  158.65.110.212-239.255.255.250-50121-1900-17  158.65.110.212
# 2           2            172.16.0.11-212.95.7.75-2795-53-17     172.16.0.11
# 3           3         172.16.0.11-66.186.178.177-10131-25-6     172.16.0.11
#
#    Src Port           Dst IP  Dst Port  Protocol               Timestamp  \
# 0      4539      212.95.7.75        53        17  07/10/2010 05:10:25 AM
# 1     50121  239.255.255.250      1900        17  12/10/2012 07:16:45 AM
# 2      2795      212.95.7.75        53        17  07/10/2010 05:09:49 AM
# 3     10131   66.186.178.177        25         6  07/10/2010 05:12:24 AM
#
#    Flow Duration  Total Fwd Packet  ...  Fwd Seg Size Min  Active Mean  \
# 0          68216                 1  ...                 8          0.0
# 1       15047465                 6  ...                 8          0.0
# ...

# %%
data.loc[(data['Label']=='NeedManualLabel'), 'Label'] = 1
data.head(4)
# Out:
#    Unnamed: 0                                       Flow ID          Src IP  \
# 0           0            172.16.0.11-212.95.7.75-4539-53-17     172.16.0.11
# 1           1  158.65.110.212-239.255.255.250-50121-1900-17  158.65.110.212
# 2           2            172.16.0.11-212.95.7.75-2795-53-17     172.16.0.11
# 3           3         172.16.0.11-66.186.178.177-10131-25-6     172.16.0.11
#
#    Src Port           Dst IP  Dst Port  Protocol               Timestamp  \
# 0      4539      212.95.7.75        53        17  07/10/2010 05:10:25 AM
# 1     50121  239.255.255.250      1900        17  12/10/2012 07:16:45 AM
# 2      2795      212.95.7.75        53        17  07/10/2010 05:09:49 AM
# 3     10131   66.186.178.177        25         6  07/10/2010 05:12:24 AM
#
#    Flow Duration  Total Fwd Packet  ...  Fwd Seg Size Min  Active Mean  \
# 0          68216                 1  ...                 8          0.0
# 1       15047465                 6  ...                 8          0.0
# ...

# %%
data['Label'].value_counts()
# Out:
# 0     1828
# 1     1828
# 3     1828
# 4     1828
# 5     1828
# 7     1828
# 10    1828
# 12    1828
# Name: Label, dtype: int64

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)
data.head(3)
# Out:
#                                         Flow ID          Src IP  Src Port  \
# 0            172.16.0.11-212.95.7.75-4539-53-17     172.16.0.11      4539
# 1  158.65.110.212-239.255.255.250-50121-1900-17  158.65.110.212     50121
# 2            172.16.0.11-212.95.7.75-2795-53-17     172.16.0.11      2795
#
#             Dst IP  Dst Port  Protocol               Timestamp  Flow Duration  \
# 0      212.95.7.75        53        17  07/10/2010 05:10:25 AM          68216
# 1  239.255.255.250      1900        17  12/10/2012 07:16:45 AM       15047465
# 2      212.95.7.75        53        17  07/10/2010 05:09:49 AM          77108
#
#    Total Fwd Packet  Total Bwd packets  ...  Fwd Seg Size Min  Active Mean  \
# 0                 1                  1  ...                 8          0.0
# 1                 6                  0  ...                 8          0.0
# 2                 1                  1  ...                 8          0.0
#
# ...

# %%
data.shape
# Out:
# (14624, 84)

# %%
data['Label'].value_counts()
# Out:
# 0     1828
# 1     1828
# 3     1828
# 4     1828
# 5     1828
# 7     1828
# 10    1828
# 12    1828
# Name: Label, dtype: int64

# %%
new_feature = [
    'flow_id',
    'src_ip',
    'src_port',
    'dst_ip',
    'dst_port',
    'protocol',
    'timestamp',
    'flow_duration',
    'total_fwd_packet',
    'total_bwd_packets',
    'total_length_of_fwd_packet',
    'total_length_of_bwd_packet',
    'fwd_packet_length_max',
    'fwd_packet_length_min',
    'fwd_packet_length_mean',
    'fwd_packet_length_std',
    'bwd_packet_length_max',
    'bwd_packet_length_min',
    'bwd_packet_length_mean',
    'bwd_packet_length_std',
    'flow_bytes_per_s',
    'flow_packets_per_s',
    'flow_iat_mean',
    'flow_iat_std',
    'flow_iat_max',
    'flow_iat_min',
    'fwd_iat_total',
    'fwd_iat_mean',
    'fwd_iat_std',
    'fwd_iat_max',
    'fwd_iat_min',
    'bwd_iat_total',
    'bwd_iat_mean',
    'bwd_iat_std',
    'bwd_iat_max',
    'bwd_iat_min',
    'fwd_psh_flags',
    'bwd_psh_flags',
    'fwd_urg_flags',
    'bwd_urg_flags',
    'fwd_header_length',
    'bwd_header_length',
    'fwd_packets_per_s',
    'bwd_packets_per_s',
    'packet_length_min',
    'packet_length_max',
    'packet_length_mean',
    'packet_length_std',
    'packet_length_variance',
    'fin_flag_count',
    'syn_flag_count',
    'rst_flag_count',
    'psh_flag_count',
    'ack_flag_count',
    'urg_flag_count',
    'cwr_flag_count',
    'ece_flag_count',
    'down_per_up_ratio',
    'average_packet_size',
    'fwd_segment_size_avg',
    'bwd_segment_size_avg',
    'fwd_bytes_per_bulk_avg',
    'fwd_packet_per_bulk_avg',
    'fwd_bulk_rate_avg',
    'bwd_bytes_per_bulk_avg',
    'bwd_packet_per_bulk_avg',
    'bwd_bulk_rate_avg',
    'subflow_fwd_packets',
    'subflow_fwd_bytes',
    'subflow_bwd_packets',
    'subflow_bwd_bytes',
    'fwd_init_win_bytes',
    'bwd_init_win_bytes',
    'fwd_act_data_pkts',
    'fwd_seg_size_min',
    'active_mean',
    'active_std',
    'active_max',
    'active_min',
    'idle_mean',
    'idle_std',
    'idle_max',
    'idle_min',
    'label'
]

# %%
len(new_feature)
# Out:
# 84

# %%
a = new_feature 
b = data.columns

for i in range (0, len(data.columns)):
    print(str(a[i] ) + "  <-> " + str(b[i]) + " no  " + str(i))
# Out:
# flow_id  <-> Flow ID no  0
# src_ip  <-> Src IP no  1
# src_port  <-> Src Port no  2
# dst_ip  <-> Dst IP no  3
# dst_port  <-> Dst Port no  4
# protocol  <-> Protocol no  5
# timestamp  <-> Timestamp no  6
# flow_duration  <-> Flow Duration no  7
# total_fwd_packet  <-> Total Fwd Packet no  8
# total_bwd_packets  <-> Total Bwd packets no  9
# total_length_of_fwd_packet  <-> Total Length of Fwd Packet no  10
# total_length_of_bwd_packet  <-> Total Length of Bwd Packet no  11
# fwd_packet_length_max  <-> Fwd Packet Length Max no  12
# fwd_packet_length_min  <-> Fwd Packet Length Min no  13
# fwd_packet_length_mean  <-> Fwd Packet Length Mean no  14
# fwd_packet_length_std  <-> Fwd Packet Length Std no  15
# bwd_packet_length_max  <-> Bwd Packet Length Max no  16
# bwd_packet_length_min  <-> Bwd Packet Length Min no  17
# bwd_packet_length_mean  <-> Bwd Packet Length Mean no  18
# bwd_packet_length_std  <-> Bwd Packet Length Std no  19
# flow_bytes_per_s  <-> Flow Bytes/s no  20
# ...

# %%
dictionary = dict(zip(data.columns, new_feature))

# %%
dictionary
# Out:
# {'Flow ID': 'flow_id',
#  'Src IP': 'src_ip',
#  'Src Port': 'src_port',
#  'Dst IP': 'dst_ip',
#  'Dst Port': 'dst_port',
#  'Protocol': 'protocol',
#  'Timestamp': 'timestamp',
#  'Flow Duration': 'flow_duration',
#  'Total Fwd Packet': 'total_fwd_packet',
#  'Total Bwd packets': 'total_bwd_packets',
#  'Total Length of Fwd Packet': 'total_length_of_fwd_packet',
#  'Total Length of Bwd Packet': 'total_length_of_bwd_packet',
#  'Fwd Packet Length Max': 'fwd_packet_length_max',
#  'Fwd Packet Length Min': 'fwd_packet_length_min',
#  'Fwd Packet Length Mean': 'fwd_packet_length_mean',
#  'Fwd Packet Length Std': 'fwd_packet_length_std',
#  'Bwd Packet Length Max': 'bwd_packet_length_max',
#  'Bwd Packet Length Min': 'bwd_packet_length_min',
#  'Bwd Packet Length Mean': 'bwd_packet_length_mean',
#  'Bwd Packet Length Std': 'bwd_packet_length_std',
#  'Flow Bytes/s': 'flow_bytes_per_s',
#  'Flow Packets/s': 'flow_packets_per_s',
#  'Flow IAT Mean': 'flow_iat_mean',
# ...

# %%
data = data.rename(columns=dictionary)
data.head(3)
# Out:
#                                         flow_id          src_ip  src_port  \
# 0            172.16.0.11-212.95.7.75-4539-53-17     172.16.0.11      4539
# 1  158.65.110.212-239.255.255.250-50121-1900-17  158.65.110.212     50121
# 2            172.16.0.11-212.95.7.75-2795-53-17     172.16.0.11      2795
#
#             dst_ip  dst_port  protocol               timestamp  flow_duration  \
# 0      212.95.7.75        53        17  07/10/2010 05:10:25 AM          68216
# 1  239.255.255.250      1900        17  12/10/2012 07:16:45 AM       15047465
# 2      212.95.7.75        53        17  07/10/2010 05:09:49 AM          77108
#
#    total_fwd_packet  total_bwd_packets  ...  fwd_seg_size_min  active_mean  \
# 0                 1                  1  ...                 8          0.0
# 1                 6                  0  ...                 8          0.0
# 2                 1                  1  ...                 8          0.0
#
# ...

# %%
#khusus data testing baru
#reindex seperti data sensor

reindex = [
    'flow_id',
    'src_ip',
    'src_port',
    'dst_ip',
    'dst_port',
    'protocol',
    'timestamp',
    'flow_duration',
    'total_fwd_packet',
    'total_bwd_packets',
    'total_length_of_fwd_packet',
    'total_length_of_bwd_packet',
    'fwd_packet_length_max',
    'fwd_packet_length_min',
    'fwd_packet_length_mean',
    'fwd_packet_length_std',
    'bwd_packet_length_max',
    'bwd_packet_length_min',
    'bwd_packet_length_mean',
    'bwd_packet_length_std',
    'flow_bytes_per_s',
    'flow_packets_per_s',
    'flow_iat_mean',
    'flow_iat_std',
    'flow_iat_max',
    'flow_iat_min',
    'fwd_iat_total',
    'fwd_iat_mean',
    'fwd_iat_std',
    'fwd_iat_max',
    'fwd_iat_min',
    'bwd_iat_total',
    'bwd_iat_mean',
    'bwd_iat_std',
    'bwd_iat_max',
    'bwd_iat_min',
    'fwd_psh_flags',
    'bwd_psh_flags',
    'fwd_urg_flags',
    'bwd_urg_flags',
    'fwd_header_length',
    'bwd_header_length',
    'fwd_packets_per_s',
    'bwd_packets_per_s',
    'packet_length_min',
    'packet_length_max',
    'packet_length_mean',
    'packet_length_std',
    'packet_length_variance',
    'fin_flag_count',
    'syn_flag_count',
    'rst_flag_count',
    'psh_flag_count',
    'ack_flag_count',
    'urg_flag_count',
    'cwr_flag_count',
    'ece_flag_count',
    'down_per_up_ratio',
    'average_packet_size',
    'fwd_segment_size_avg',
    'bwd_segment_size_avg',
    'fwd_bytes_per_bulk_avg',
    'fwd_packet_per_bulk_avg',
    'fwd_bulk_rate_avg',
    'bwd_bytes_per_bulk_avg',
    'bwd_packet_per_bulk_avg',
    'bwd_bulk_rate_avg',
    'subflow_fwd_packets',
    'subflow_fwd_bytes',
    'subflow_bwd_packets',
    'subflow_bwd_bytes',
    'fwd_init_win_bytes',
    'bwd_init_win_bytes',
    'fwd_act_data_pkts',
    'fwd_seg_size_min',
    'active_mean',
    'active_std',
    'active_max',
    'active_min',
    'idle_mean',
    'idle_std',
    'idle_max',
    'idle_min',
    'label'
]

# %%
dataRe = data.reindex(columns=reindex)
dataRe.head(3)
# Out:
#                                         flow_id          src_ip  src_port  \
# 0            172.16.0.11-212.95.7.75-4539-53-17     172.16.0.11      4539
# 1  158.65.110.212-239.255.255.250-50121-1900-17  158.65.110.212     50121
# 2            172.16.0.11-212.95.7.75-2795-53-17     172.16.0.11      2795
#
#             dst_ip  dst_port  protocol               timestamp  flow_duration  \
# 0      212.95.7.75        53        17  07/10/2010 05:10:25 AM          68216
# 1  239.255.255.250      1900        17  12/10/2012 07:16:45 AM       15047465
# 2      212.95.7.75        53        17  07/10/2010 05:09:49 AM          77108
#
#    total_fwd_packet  total_bwd_packets  ...  fwd_seg_size_min  active_mean  \
# 0                 1                  1  ...                 8          0.0
# 1                 6                  0  ...                 8          0.0
# 2                 1                  1  ...                 8          0.0
#
# ...

# %%
dataRe.shape
# Out:
# (14624, 84)

# %%
dataRe['label'].value_counts()
# Out:
# 0     1828
# 1     1828
# 3     1828
# 4     1828
# 5     1828
# 7     1828
# 10    1828
# 12    1828
# Name: label, dtype: int64

# %%
dataRe.to_csv(write_path, index=True)
